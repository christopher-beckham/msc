# %%
import sys
import os
from skimage.io import imread, imsave
from skimage import img_as_float, img_as_ubyte
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = imread("/Volumes/CB_RESEARCH/heightmaps/si1 terrain/si1 Height Map (Merged).png")
plt.imshow( img, cmap="gray")

# %%
crop_size = 256

# %%
offset = 20
chunks = []
for y in range(0, img.shape[0] - crop_size+1, offset):
    for x in range(0, img.shape[1]-crop_size+1, offset):
        chunk = img[ y:y+crop_size, x:x+crop_size ]
        print chunk.shape
        chunks.append(chunk)
    break
# Out:
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)

# %%
plt.imshow( chunks[15], cmap="gray" )

# %%
scipy.misc.imsave("/tmp/stuff.png", chunks[15])

# %%
import scipy.misc

# %%
scipy.misc.imsave
# Out:
# <function scipy.misc.pilutil.imsave>
